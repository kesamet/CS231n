# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.395313
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.737326 analytic: -0.737326, relative error: 3.005157e-08
# numerical: -1.580649 analytic: -1.580649, relative error: 1.781658e-08
# numerical: -0.617158 analytic: -0.617158, relative error: 6.666960e-08
# numerical: 1.252634 analytic: 1.252634, relative error: 6.311715e-08
# numerical: 2.024466 analytic: 2.024466, relative error: 3.628886e-08
# numerical: 0.333088 analytic: 0.333088, relative error: 8.909534e-08
# numerical: 0.531423 analytic: 0.531423, relative error: 4.190515e-08
# numerical: -0.167813 analytic: -0.167813, relative error: 2.567900e-07
# numerical: 3.276901 analytic: 3.276901, relative error: 1.108288e-08
# numerical: -0.969304 analytic: -0.969303, relative error: 3.240841e-08
# numerical: 0.096683 analytic: 0.096683, relative error: 4.829492e-07
# numerical: -0.953810 analytic: -0.953810, relative error: 1.159445e-08
# numerical: -1.802201 analytic: -1.802201, relative error: 9.382702e-09
# numerical: 2.593189 analytic: 2.593189, relative error: 2.716511e-08
# numerical: -2.378002 analytic: -2.378002, relative error: 6.853714e-09
# numerical: 1.884745 analytic: 1.884745, relative error: 7.899285e-09
# numerical: -2.375632 analytic: -2.375632, relative error: 1.289395e-08
# numerical: -0.829224 analytic: -0.829224, relative error: 2.633356e-08
# numerical: -0.912247 analytic: -0.912247, relative error: 1.019594e-08
# numerical: 1.498013 analytic: 1.498013, relative error: 4.681689e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.395313e+00 computed in 0.044265s
# vectorized loss: 2.395313e+00 computed in 0.009379s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
num_trials = 20
for _ in range(num_trials):
    lr = 10 ** np.random.uniform(np.log10(learning_rates[0]), np.log10(learning_rates[1]))
    reg = 10 ** np.random.uniform(np.log10(regularization_strengths[0]), np.log10(regularization_strengths[1]))
    print('... Trying lr = %e & reg = %e' % (lr, reg))
    
    softmax = Softmax()
    _ = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
    y_train_pred = softmax.predict(X_train)
    y_val_pred = softmax.predict(X_val)
    train_accuracy = np.mean(y_train == y_train_pred)
    val_accuracy = np.mean(y_val == y_val_pred)
    results[(lr, reg)] = [train_accuracy, val_accuracy]
    if val_accuracy > best_val:
        best_val = val_accuracy
        best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# ... Trying lr = 1.774905e-07 & reg = 2.900877e+04
# iteration 0 / 1500: loss 910.565374
# iteration 100 / 1500: loss 116.016197
# iteration 200 / 1500: loss 16.415474
# iteration 300 / 1500: loss 3.891603
# iteration 400 / 1500: loss 2.300402
# iteration 500 / 1500: loss 2.139125
# iteration 600 / 1500: loss 2.099959
# iteration 700 / 1500: loss 2.069561
# iteration 800 / 1500: loss 2.114918
# iteration 900 / 1500: loss 2.155289
# iteration 1000 / 1500: loss 2.127654
# iteration 1100 / 1500: loss 2.118040
# iteration 1200 / 1500: loss 2.091430
# iteration 1300 / 1500: loss 2.127746
# iteration 1400 / 1500: loss 2.126743
# ... Trying lr = 2.105040e-07 & reg = 2.719940e+04
# iteration 0 / 1500: loss 844.287409
# iteration 100 / 1500: loss 85.723875
# iteration 200 / 1500: loss 10.348533
# iteration 300 / 1500: loss 2.944714
# iteration 400 / 1500: loss 2.125076
# iteration 500 / 1500: loss 2.099350
# iteration 600 / 1500: loss 2.057828
# iteration 700 / 1500: loss 2.101767
# iteration 800 / 1500: loss 2.049168
# iteration 900 / 1500: loss 2.100465
# iteration 1000 / 1500: loss 2.105221
# iteration 1100 / 1500: loss 2.099494
# iteration 1200 / 1500: loss 2.106800
# iteration 1300 / 1500: loss 2.055358
# iteration 1400 / 1500: loss 2.087623
# ... Trying lr = 2.232965e-07 & reg = 3.267900e+04
# iteration 0 / 1500: loss 998.707791
# iteration 100 / 1500: loss 54.230745
# iteration 200 / 1500: loss 4.848049
# iteration 300 / 1500: loss 2.285631
# iteration 400 / 1500: loss 2.086786
# iteration 500 / 1500: loss 2.051963
# iteration 600 / 1500: loss 2.146663
# iteration 700 / 1500: loss 2.107937
# iteration 800 / 1500: loss 2.078100
# iteration 900 / 1500: loss 2.131499
# iteration 1000 / 1500: loss 2.112058
# iteration 1100 / 1500: loss 2.073032
# iteration 1200 / 1500: loss 2.069456
# iteration 1300 / 1500: loss 2.102813
# iteration 1400 / 1500: loss 2.099652
# ... Trying lr = 4.403153e-07 & reg = 4.308210e+04
# iteration 0 / 1500: loss 1329.274118
# iteration 100 / 1500: loss 2.750565
# iteration 200 / 1500: loss 2.132160
# iteration 300 / 1500: loss 2.157078
# iteration 400 / 1500: loss 2.114774
# iteration 500 / 1500: loss 2.116227
# iteration 600 / 1500: loss 2.114314
# iteration 700 / 1500: loss 2.119493
# iteration 800 / 1500: loss 2.156996
# iteration 900 / 1500: loss 2.125925
# iteration 1000 / 1500: loss 2.128267
# iteration 1100 / 1500: loss 2.106232
# iteration 1200 / 1500: loss 2.135929
# iteration 1300 / 1500: loss 2.138329
# iteration 1400 / 1500: loss 2.124000
# ... Trying lr = 2.039049e-07 & reg = 3.277609e+04
# iteration 0 / 1500: loss 1017.069644
# iteration 100 / 1500: loss 70.526362
# iteration 200 / 1500: loss 6.739673
# iteration 300 / 1500: loss 2.443286
# iteration 400 / 1500: loss 2.139584
# iteration 500 / 1500: loss 2.106832
# iteration 600 / 1500: loss 2.091743
# iteration 700 / 1500: loss 2.072767
# iteration 800 / 1500: loss 2.118705
# iteration 900 / 1500: loss 2.109605
# iteration 1000 / 1500: loss 2.113713
# iteration 1100 / 1500: loss 2.094842
# iteration 1200 / 1500: loss 2.104516
# iteration 1300 / 1500: loss 2.130003
# iteration 1400 / 1500: loss 2.130257
# ... Trying lr = 1.060633e-07 & reg = 2.725741e+04
# iteration 0 / 1500: loss 840.708774
# iteration 100 / 1500: loss 263.044205
# iteration 200 / 1500: loss 83.665519
# iteration 300 / 1500: loss 27.556039
# iteration 400 / 1500: loss 10.019419
# iteration 500 / 1500: loss 4.595928
# iteration 600 / 1500: loss 2.846201
# iteration 700 / 1500: loss 2.344294
# iteration 800 / 1500: loss 2.161757
# iteration 900 / 1500: loss 2.119229
# iteration 1000 / 1500: loss 2.115474
# iteration 1100 / 1500: loss 2.096506
# iteration 1200 / 1500: loss 2.132322
# iteration 1300 / 1500: loss 2.146123
# iteration 1400 / 1500: loss 2.103596
# ... Trying lr = 3.510394e-07 & reg = 3.373317e+04
# iteration 0 / 1500: loss 1053.760581
# iteration 100 / 1500: loss 10.710949
# iteration 200 / 1500: loss 2.182016
# iteration 300 / 1500: loss 2.127786
# iteration 400 / 1500: loss 2.164162
# iteration 500 / 1500: loss 2.156713
# iteration 600 / 1500: loss 2.106625
# iteration 700 / 1500: loss 2.119365
# iteration 800 / 1500: loss 2.160922
# iteration 900 / 1500: loss 2.170505
# iteration 1000 / 1500: loss 2.069319
# iteration 1100 / 1500: loss 2.066919
# iteration 1200 / 1500: loss 2.073178
# iteration 1300 / 1500: loss 2.145357
# iteration 1400 / 1500: loss 2.101649
# ... Trying lr = 4.352006e-07 & reg = 3.319169e+04
# iteration 0 / 1500: loss 1044.041480
# iteration 100 / 1500: loss 5.034479
# iteration 200 / 1500: loss 2.091810
# iteration 300 / 1500: loss 2.129045
# iteration 400 / 1500: loss 2.125920
# iteration 500 / 1500: loss 2.148733
# iteration 600 / 1500: loss 2.077204
# iteration 700 / 1500: loss 2.087583
# iteration 800 / 1500: loss 2.044809
# iteration 900 / 1500: loss 2.119171
# iteration 1000 / 1500: loss 2.086290
# iteration 1100 / 1500: loss 2.183113
# iteration 1200 / 1500: loss 2.094412
# iteration 1300 / 1500: loss 2.059247
# iteration 1400 / 1500: loss 2.086778
# ... Trying lr = 3.528172e-07 & reg = 2.610712e+04
# iteration 0 / 1500: loss 819.992793
# iteration 100 / 1500: loss 21.753476
# iteration 200 / 1500: loss 2.564007
# iteration 300 / 1500: loss 2.089557
# iteration 400 / 1500: loss 2.057812
# iteration 500 / 1500: loss 2.031138
# iteration 600 / 1500: loss 2.112402
# iteration 700 / 1500: loss 2.094851
# iteration 800 / 1500: loss 2.094837
# iteration 900 / 1500: loss 2.059347
# iteration 1000 / 1500: loss 2.028556
# iteration 1100 / 1500: loss 2.136100
# iteration 1200 / 1500: loss 2.080639
# iteration 1300 / 1500: loss 2.080831
# iteration 1400 / 1500: loss 2.072701
# ... Trying lr = 3.540077e-07 & reg = 2.952036e+04
# iteration 0 / 1500: loss 912.752329
# iteration 100 / 1500: loss 15.335064
# iteration 200 / 1500: loss 2.264501
# iteration 300 / 1500: loss 2.087155
# iteration 400 / 1500: loss 2.059194
# iteration 500 / 1500: loss 2.173632
# iteration 600 / 1500: loss 2.133798
# iteration 700 / 1500: loss 2.074969
# iteration 800 / 1500: loss 2.123905
# iteration 900 / 1500: loss 2.092815
# iteration 1000 / 1500: loss 2.117429
# iteration 1100 / 1500: loss 2.114947
# iteration 1200 / 1500: loss 2.037763
# iteration 1300 / 1500: loss 2.153320
# iteration 1400 / 1500: loss 2.117961
# ... Trying lr = 1.548668e-07 & reg = 2.857151e+04
# iteration 0 / 1500: loss 887.354119
# iteration 100 / 1500: loss 150.926164
# iteration 200 / 1500: loss 27.145177
# iteration 300 / 1500: loss 6.264439
# iteration 400 / 1500: loss 2.800850
# iteration 500 / 1500: loss 2.195001
# iteration 600 / 1500: loss 2.115099
# iteration 700 / 1500: loss 2.118604
# iteration 800 / 1500: loss 2.116795
# iteration 900 / 1500: loss 2.111385
# iteration 1000 / 1500: loss 2.061427
# iteration 1100 / 1500: loss 2.111821
# iteration 1200 / 1500: loss 2.109117
# iteration 1300 / 1500: loss 2.118417
# iteration 1400 / 1500: loss 2.046387
# ... Trying lr = 3.953031e-07 & reg = 4.826505e+04
# iteration 0 / 1500: loss 1505.587262
# iteration 100 / 1500: loss 2.801482
# iteration 200 / 1500: loss 2.137378
# iteration 300 / 1500: loss 2.110689
# iteration 400 / 1500: loss 2.090346
# iteration 500 / 1500: loss 2.176453
# iteration 600 / 1500: loss 2.155674
# iteration 700 / 1500: loss 2.124869
# iteration 800 / 1500: loss 2.147570
# iteration 900 / 1500: loss 2.130508
# iteration 1000 / 1500: loss 2.124654
# iteration 1100 / 1500: loss 2.147070
# iteration 1200 / 1500: loss 2.106108
# iteration 1300 / 1500: loss 2.140987
# iteration 1400 / 1500: loss 2.085805
# ... Trying lr = 3.549279e-07 & reg = 4.046887e+04
# iteration 0 / 1500: loss 1241.073434
# iteration 100 / 1500: loss 5.738663
# iteration 200 / 1500: loss 2.130728
# iteration 300 / 1500: loss 2.124264
# iteration 400 / 1500: loss 2.182867
# iteration 500 / 1500: loss 2.149136
# iteration 600 / 1500: loss 2.114507
# iteration 700 / 1500: loss 2.140454
# iteration 800 / 1500: loss 2.132429
# iteration 900 / 1500: loss 2.142046
# iteration 1000 / 1500: loss 2.067490
# iteration 1100 / 1500: loss 2.123566
# iteration 1200 / 1500: loss 2.150491
# iteration 1300 / 1500: loss 2.082897
# iteration 1400 / 1500: loss 2.130727
# ... Trying lr = 2.575422e-07 & reg = 3.108769e+04
# iteration 0 / 1500: loss 958.123216
# iteration 100 / 1500: loss 39.643395
# iteration 200 / 1500: loss 3.546756
# iteration 300 / 1500: loss 2.187095
# iteration 400 / 1500: loss 2.065267
# iteration 500 / 1500: loss 2.077192
# iteration 600 / 1500: loss 2.136073
# iteration 700 / 1500: loss 2.076934
# iteration 800 / 1500: loss 2.088373
# iteration 900 / 1500: loss 2.134647
# iteration 1000 / 1500: loss 2.111817
# iteration 1100 / 1500: loss 2.122217
# iteration 1200 / 1500: loss 2.105377
# iteration 1300 / 1500: loss 2.161010
# iteration 1400 / 1500: loss 2.069514
# ... Trying lr = 4.603799e-07 & reg = 4.670135e+04
# iteration 0 / 1500: loss 1436.193545
# iteration 100 / 1500: loss 2.402998
# iteration 200 / 1500: loss 2.176238
# iteration 300 / 1500: loss 2.149227
# iteration 400 / 1500: loss 2.115969
# iteration 500 / 1500: loss 2.146640
# iteration 600 / 1500: loss 2.121226
# iteration 700 / 1500: loss 2.145149
# iteration 800 / 1500: loss 2.166504
# iteration 900 / 1500: loss 2.159539
# iteration 1000 / 1500: loss 2.139305
# iteration 1100 / 1500: loss 2.140911
# iteration 1200 / 1500: loss 2.106040
# iteration 1300 / 1500: loss 2.171408
# iteration 1400 / 1500: loss 2.124653
# ... Trying lr = 3.708549e-07 & reg = 3.348591e+04
# iteration 0 / 1500: loss 1036.537403
# iteration 100 / 1500: loss 8.791333
# iteration 200 / 1500: loss 2.097871
# iteration 300 / 1500: loss 2.057067
# iteration 400 / 1500: loss 2.130337
# iteration 500 / 1500: loss 2.143242
# iteration 600 / 1500: loss 2.063560
# iteration 700 / 1500: loss 2.131620
# iteration 800 / 1500: loss 2.108881
# iteration 900 / 1500: loss 2.092737
# iteration 1000 / 1500: loss 2.091482
# iteration 1100 / 1500: loss 2.134435
# iteration 1200 / 1500: loss 2.116638
# iteration 1300 / 1500: loss 2.095059
# iteration 1400 / 1500: loss 2.105780
# ... Trying lr = 4.740970e-07 & reg = 3.639694e+04
# iteration 0 / 1500: loss 1141.395910
# iteration 100 / 1500: loss 3.122965
# iteration 200 / 1500: loss 2.160769
# iteration 300 / 1500: loss 2.182331
# iteration 400 / 1500: loss 2.125773
# iteration 500 / 1500: loss 2.128085
# iteration 600 / 1500: loss 2.157892
# iteration 700 / 1500: loss 2.162887
# iteration 800 / 1500: loss 2.064947
# iteration 900 / 1500: loss 2.140408
# iteration 1000 / 1500: loss 2.119745
# iteration 1100 / 1500: loss 2.146814
# iteration 1200 / 1500: loss 2.116581
# iteration 1300 / 1500: loss 2.095282
# iteration 1400 / 1500: loss 2.094807
# ... Trying lr = 1.536702e-07 & reg = 4.585677e+04
# iteration 0 / 1500: loss 1406.383449
# iteration 100 / 1500: loss 83.716617
# iteration 200 / 1500: loss 6.876639
# iteration 300 / 1500: loss 2.424544
# iteration 400 / 1500: loss 2.119982
# iteration 500 / 1500: loss 2.145489
# iteration 600 / 1500: loss 2.186075
# iteration 700 / 1500: loss 2.129080
# iteration 800 / 1500: loss 2.146045
# iteration 900 / 1500: loss 2.076644
# iteration 1000 / 1500: loss 2.190802
# iteration 1100 / 1500: loss 2.189176
# iteration 1200 / 1500: loss 2.207534
# iteration 1300 / 1500: loss 2.155307
# iteration 1400 / 1500: loss 2.108744
# ... Trying lr = 2.380430e-07 & reg = 4.000384e+04
# iteration 0 / 1500: loss 1230.753269
# iteration 100 / 1500: loss 28.212512
# iteration 200 / 1500: loss 2.650548
# iteration 300 / 1500: loss 2.151130
# iteration 400 / 1500: loss 2.107246
# iteration 500 / 1500: loss 2.101244
# iteration 600 / 1500: loss 2.115468
# iteration 700 / 1500: loss 2.120327
# iteration 800 / 1500: loss 2.137353
# iteration 900 / 1500: loss 2.202237
# iteration 1000 / 1500: loss 2.080813
# iteration 1100 / 1500: loss 2.157540
# iteration 1200 / 1500: loss 2.158221
# iteration 1300 / 1500: loss 2.098908
# iteration 1400 / 1500: loss 2.161705
# ... Trying lr = 1.062391e-07 & reg = 4.819912e+04
# iteration 0 / 1500: loss 1478.851807
# iteration 100 / 1500: loss 189.959588
# iteration 200 / 1500: loss 26.032334
# iteration 300 / 1500: loss 5.174416
# iteration 400 / 1500: loss 2.514045
# iteration 500 / 1500: loss 2.187535
# iteration 600 / 1500: loss 2.174960
# iteration 700 / 1500: loss 2.150744
# iteration 800 / 1500: loss 2.171995
# iteration 900 / 1500: loss 2.138029
# iteration 1000 / 1500: loss 2.122530
# iteration 1100 / 1500: loss 2.118315
# iteration 1200 / 1500: loss 2.130867
# iteration 1300 / 1500: loss 2.099506
# iteration 1400 / 1500: loss 2.162316
# lr 1.060633e-07 reg 2.725741e+04 train accuracy: 0.321245 val accuracy: 0.340000
# lr 1.062391e-07 reg 4.819912e+04 train accuracy: 0.305020 val accuracy: 0.320000
# lr 1.536702e-07 reg 4.585677e+04 train accuracy: 0.308367 val accuracy: 0.323000
# lr 1.548668e-07 reg 2.857151e+04 train accuracy: 0.327082 val accuracy: 0.344000
# lr 1.774905e-07 reg 2.900877e+04 train accuracy: 0.319857 val accuracy: 0.329000
# lr 2.039049e-07 reg 3.277609e+04 train accuracy: 0.312286 val accuracy: 0.323000
# lr 2.105040e-07 reg 2.719940e+04 train accuracy: 0.321653 val accuracy: 0.338000
# lr 2.232965e-07 reg 3.267900e+04 train accuracy: 0.315143 val accuracy: 0.338000
# lr 2.380430e-07 reg 4.000384e+04 train accuracy: 0.320143 val accuracy: 0.332000
# lr 2.575422e-07 reg 3.108769e+04 train accuracy: 0.329102 val accuracy: 0.338000
# lr 3.510394e-07 reg 3.373317e+04 train accuracy: 0.316939 val accuracy: 0.337000
# lr 3.528172e-07 reg 2.610712e+04 train accuracy: 0.336102 val accuracy: 0.341000
# lr 3.540077e-07 reg 2.952036e+04 train accuracy: 0.323367 val accuracy: 0.334000
# lr 3.549279e-07 reg 4.046887e+04 train accuracy: 0.310592 val accuracy: 0.317000
# lr 3.708549e-07 reg 3.348591e+04 train accuracy: 0.311122 val accuracy: 0.331000
# lr 3.953031e-07 reg 4.826505e+04 train accuracy: 0.301714 val accuracy: 0.321000
# lr 4.352006e-07 reg 3.319169e+04 train accuracy: 0.311551 val accuracy: 0.326000
# lr 4.403153e-07 reg 4.308210e+04 train accuracy: 0.313571 val accuracy: 0.326000
# lr 4.603799e-07 reg 4.670135e+04 train accuracy: 0.310469 val accuracy: 0.321000
# lr 4.740970e-07 reg 3.639694e+04 train accuracy: 0.315000 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.344000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.340000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
